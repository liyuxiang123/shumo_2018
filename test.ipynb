# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

Data_01 = [(264,715),(258,719),(274,728),(264,728),(254,728),(257,733),(260,731),
         (262,733),(268,733),(270,739)]
Data_02 = [(225,605),(223,598),(210,605),(220,610),(223,615),(209,615),(230,620),
         (220,622),(205,618)]
Data_03 = [(168,538),(168,542),(164,544),(168,545),(174,544)]
Data_04 = [(210,455),(180,455),(175,452),(170,453),(185,460),(178,460),(190,470),
         (183,473),(175,472),(180,476)]
Data_05 = [(120,400),(119,388),(112,394),(125,410),(114,405),(116,410),(113,416)]
Data_06 = [(96,304),(88,305),(100,312),(93,311),(86,310),(94,315)]
Data_07 = [(10,451),(11,449),(13,450),(16,450),(12,453),(15,455)]
Data_08 = [(162,660),(161,659),(159,659),(160,657),(164,658)]
Data_09 = [(110,561),(110,563),(110,565),(109,567),(112,568)]
Data_10 = [(105,473),(106,471),(103,473),(107,475),(104,477)]

# %%
data = pd.DataFrame([Data_01,Data_02,Data_03,Data_04,Data_05,
                    Data_06,Data_07,Data_08,Data_09,Data_10])

# %%
data
# Out:
#             0           1           2           3           4           5  \
# 0  (264, 715)  (258, 719)  (274, 728)  (264, 728)  (254, 728)  (257, 733)
# 1  (225, 605)  (223, 598)  (210, 605)  (220, 610)  (223, 615)  (209, 615)
# 2  (168, 538)  (168, 542)  (164, 544)  (168, 545)  (174, 544)        None
# 3  (210, 455)  (180, 455)  (175, 452)  (170, 453)  (185, 460)  (178, 460)
# 4  (120, 400)  (119, 388)  (112, 394)  (125, 410)  (114, 405)  (116, 410)
# 5   (96, 304)   (88, 305)  (100, 312)   (93, 311)   (86, 310)   (94, 315)
# 6   (10, 451)   (11, 449)   (13, 450)   (16, 450)   (12, 453)   (15, 455)
# 7  (162, 660)  (161, 659)  (159, 659)  (160, 657)  (164, 658)        None
# 8  (110, 561)  (110, 563)  (110, 565)  (109, 567)  (112, 568)        None
# 9  (105, 473)  (106, 471)  (103, 473)  (107, 475)  (104, 477)        None
#
#             6           7           8           9
# 0  (260, 731)  (262, 733)  (268, 733)  (270, 739)
# 1  (230, 620)  (220, 622)  (205, 618)        None
# ...

# %%
p1=plt.scatter(data[0],data[1],marker='x',color='g',label='1',s=30)
p2=plt.scatter(pd.DataFrame(Data_02)[0],pd.DataFrame(Data_02)[1],marker='+',color='r',label='2',s=30)
p3=plt.scatter(pd.DataFrame(Data_03)[0],pd.DataFrame(Data_03)[1],marker='*',color='c',label='3',s=30)
p4=plt.scatter(pd.DataFrame(Data_04)[0],pd.DataFrame(Data_04)[1],marker='+',color='r',label='2',s=30)
p5=plt.scatter(pd.DataFrame(Data_05)[0],pd.DataFrame(Data_05)[1],marker='*',color='c',label='3',s=30)
p6=plt.scatter(pd.DataFrame(Data_06)[0],pd.DataFrame(Data_06)[1],marker='+',color='r',label='2',s=30)
p7=plt.scatter(pd.DataFrame(Data_07)[0],pd.DataFrame(Data_07)[1],marker='*',color='c',label='3',s=30)
p8=plt.scatter(pd.DataFrame(Data_08)[0],pd.DataFrame(Data_08)[1],marker='+',color='r',label='2',s=30)
p9=plt.scatter(pd.DataFrame(Data_09)[0],pd.DataFrame(Data_09)[1],marker='*',color='c',label='3',s=30)
p10=plt.scatter(pd.DataFrame(Data_10)[0],pd.DataFrame(Data_10)[1],marker='*',color='c',label='3',s=30)
